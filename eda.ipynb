# %%
from data import load_steel_plates_faults
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from data import load_steel_plates_faults
#
# ModuleNotFoundError: No module named 'data'

# %%
X, y = load_steel_plates_faults()

print(X.head())
print(y.head())

print(X.shape)
print(y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X, y = load_steel_plates_faults()
#       2
#       3 print(X.head())
#       4 print(y.head())
#
# NameError: name 'load_steel_plates_faults' is not defined
